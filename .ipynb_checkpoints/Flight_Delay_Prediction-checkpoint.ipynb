# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./Flight_delay_Final.csv')

# %%
df.head()
# Out:
#    DayOfWeek        Date  DepTime  ArrTime  CRSArrTime UniqueCarrier  \
# 0          4  03-01-2019     1829     1959        1925            WN
# 1          4  03-01-2019     1937     2037        1940            WN
# 2          4  03-01-2019     1644     1845        1725            WN
# 3          4  03-01-2019     1452     1640        1625            WN
# 4          4  03-01-2019     1323     1526        1510            WN
#
#                   Airline  FlightNum TailNum  ActualElapsedTime  ...  TaxiIn  \
# 0  Southwest Airlines Co.       3920  N464WN                 90  ...       3
# 1  Southwest Airlines Co.        509  N763SW                240  ...       3
# 2  Southwest Airlines Co.       1333  N334SW                121  ...       6
# 3  Southwest Airlines Co.        675  N286WN                228  ...       7
# 4  Southwest Airlines Co.          4  N674AA                123  ...       4
#
#    TaxiOut  Cancelled  CancellationCode Diverted CarrierDelay WeatherDelay  \
# ...

# %%
# Col_Drop = ["Unnamed: 27"]
# df = df.drop(columns = Col_Drop, axis = 1)

# %%
df
# Out:
#         DayOfWeek        Date  DepTime  ArrTime  CRSArrTime UniqueCarrier  \
# 0               4  03-01-2019     1829     1959        1925            WN
# 1               4  03-01-2019     1937     2037        1940            WN
# 2               4  03-01-2019     1644     1845        1725            WN
# 3               4  03-01-2019     1452     1640        1625            WN
# 4               4  03-01-2019     1323     1526        1510            WN
# ...           ...         ...      ...      ...         ...           ...
# 484546          5  13-06-2019     1609     1942        1915            AA
# 484547          6  14-06-2019     1616     1954        1915            AA
# 484548          2  17-06-2019     1617     2002        1915            AA
# 484549          7  22-06-2019     1607     1941        1915            AA
# 484550          1  23-06-2019     1608     1933        1915            AA
#
#                        Airline  FlightNum TailNum  ActualElapsedTime  ...  \
# ...

# %%
# CL_DROP = ['OP_CARRIER_FL_NUM', 'CRS_DEP_TIME', 'WHEELS_OFF', 'WHEELS_ON', 'CRS_ARR_TIME', 'CRS_ELAPSED_TIME', 'ACTUAL_ELAPSED_TIME', 'Unnamed: 27', 'CARRIER_DELAY','LATE_AIRCRAFT_DELAY','CANCELLATION_CODE']
# df = df.drop(columns = CL_DROP, axis = 1)

# %%
df.head()

# %%
Nan_count = df['WEATHER_DELAY'].isna().sum()
Nan_count_NAS = df['NAS_DELAY'].isna().sum()
Nan_count_SEC = df['SECURITY_DELAY'].isna().sum()

# %%
print(Nan_count,Nan_count_NAS,Nan_count_SEC)

# %%
csv_row, csv_columns = df.shape

# %%
print(csv_row,csv_columns)

# %%
import pandas as pd
import random

# Load the CSV file into a pandas DataFrame
input_csv_path = './Flight_delay_Final.csv'  # Replace with the path to your CSV file
output_csv_path = './output_dataset.csv'  # Replace with the desired output path

df = pd.read_csv(input_csv_path)

# Calculate the number of rows to keep (30% of the original)
num_rows_to_keep = int(0.15 * len(df))

# Get a random sample of rows to keep
rows_to_keep = random.sample(range(len(df)), num_rows_to_keep)

# Create a new DataFrame with only the selected rows
df_filtered = df.iloc[rows_to_keep]

# Save the filtered DataFrame to a new CSV file
df_filtered.to_csv(output_csv_path, index=False)

print(f"{num_rows_to_keep} rows kept, {len(df) - num_rows_to_keep} rows deleted.")
# Out:
# 96910 rows kept, 387641 rows deleted.

# %% [markdown]
# <h3> Data Cleaning and preprocessing Block </h3>
